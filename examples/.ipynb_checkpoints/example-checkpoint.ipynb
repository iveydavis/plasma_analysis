# %%
from swabs import star, isothermal_solution, polytropic_solution, bursts
from swabs.misc import G
import matplotlib.pyplot as plt
from astropy import units as un, constants as const

# %% [markdown]
# # Solar example

# %%
sun = star.Star(M_star=1*un.M_sun, R_star=1*un.R_sun, T_phot=5700*un.K)
print(sun.__dict__)
# Out:
# {'R_star': <Quantity 6.957e+10 cm>, 'M_star': <Quantity 1.98840987e+33 g>, 'T_phot': <Quantity 5700. K>}

# %% [markdown]
# ## Isothermal solution

# %%
iso_cor = isothermal_solution.Isothermal_Corona(star=sun, mean_mol_weight=0.6, T0=2e6*un.K, n0=1e9/un.cm**3, B0=10*G)
iso_cor.calc_wind_solution(alf_dist=20*const.R_sun)
iso_cor.plot(['velocity', 'number_density'])
# Out:
# /home/idavis/anaconda3/lib/python3.9/site-packages/astropy/units/quantity.py:666: RuntimeWarning: divide by zero encountered in log
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)

# %% [markdown]
# ## Polytropic solutions

# %%
poly_idxs = [1.1, 1.3, 1.4]
poly_sols = []
fig, axs = plt.subplots()
for p in poly_idxs:
    poly_cor = polytropic_solution.Polytropic_Corona(poly_idx=p, star=sun, mean_mol_weight=0.6, T0=2e6*un.K, n0=1e9/un.cm**3, B0=10*G)
    poly_cor.calc_wind_solution(alf_dist=20*const.R_sun, max_iter=500, prec_vel=3*un.km/un.s)
    axs.plot(poly_cor.r_vec.cgs/poly_cor.star.R_star.cgs, poly_cor.velocity_profile.to('km/s'))
    poly_sols.append(poly_cor)
    
axs.set_yscale('log')
axs.set_ylabel("Wind speed [km/s]")
axs.set_xlabel(r"Distance [$R_\star$]")
# Out:
# /home/idavis/anaconda3/lib/python3.9/site-packages/astropy/units/quantity.py:666: RuntimeWarning: divide by zero encountered in true_divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/idavis/anaconda3/lib/python3.9/site-packages/astropy/units/quantity.py:666: RuntimeWarning: divide by zero encountered in true_divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /home/idavis/anaconda3/lib/python3.9/site-packages/astropy/units/quantity.py:666: RuntimeWarning: divide by zero encountered in true_divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# Text(0.5, 0, 'Distance [$R_\\star$]')

# %% [markdown]
# ## Bursts in the isothermal wind

# %%
typeii = bursts.Burst(iso_cor, 'ii', vb=700*un.km/un.s)
typeiii = bursts.Burst(iso_cor, 'iii')

# %%
typeii.make_dynamic_spectrum(nu_min=10*un.MHz, nu_max=100*un.MHz, nu_res=0.1*un.MHz, duration=60*un.min, t_res=0.5*un.s)

# %%
typeiii.make_dynamic_spectrum(nu_min=10*un.MHz, nu_max=100*un.MHz, nu_res=0.5*un.MHz, duration=2*un.min, t_res=0.1*un.s)

# %%
typeii.plot_dyn_spec()
# Out:
# (<Figure size 432x288 with 1 Axes>,
#  <AxesSubplot:xlabel='Time since flare onset [min]', ylabel='Frequency [MHz]'>)

# %%
typeiii.plot_dyn_spec()
# Out:
# (<Figure size 432x288 with 1 Axes>,
#  <AxesSubplot:xlabel='Time since flare onset [min]', ylabel='Frequency [MHz]'>)

# %% [markdown]
# ### Get de-dispersion parameters of the type III burst

# %%
typeiii.make_frequency_profile(t_res=0.1*un.s, duration=2*un.min)
typeiii.fit_drift_rate()
de_disp = typeiii.dedisperse()

plt.imshow(de_disp, aspect='auto', origin='lower')
# Out:
# /home/idavis/anaconda3/lib/python3.9/site-packages/swabs/bursts.py:280: RuntimeWarning: divide by zero encountered in log10
#   prev = np.log10(np.abs(dnudt[i-1]))
# /home/idavis/anaconda3/lib/python3.9/site-packages/swabs/bursts.py:281: RuntimeWarning: divide by zero encountered in log10
#   foll = np.log10(np.abs(dnudt[i+1]))
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [10], in <cell line: 2>()
#       1 typeiii.make_frequency_profile(t_res=0.1*un.s, duration=2*un.min)
# ----> 2 typeiii.fit_drift_rate()
#       3 de_disp = typeiii.dedisperse()
#       5 plt.imshow(de_disp, aspect='auto', origin='lower')
#
# File ~/anaconda3/lib/python3.9/site-packages/swabs/bursts.py:281, in Burst.fit_drift_rate(self, freq_range, return_profile)
#     279 if i != 0 or i <= len(dnudt) - 2:
#     280     prev = np.log10(np.abs(dnudt[i-1]))
# ...

# %%
typeiii.drift_fit_params

# %%
#### The fitting shouldn't be such shit and variable with resolution
